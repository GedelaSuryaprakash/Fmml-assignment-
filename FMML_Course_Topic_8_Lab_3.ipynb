# %% [markdown]
# <a href="https://colab.research.google.com/github/GedelaSuryaprakash/Fmml-assignment-/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-03-26 14:07:31--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.110.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   148MB/s    in 0.5s
#
# 2024-03-26 14:07:31 (148 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 3461   1706.04572v1  We present a solution to "Google Cloud and You...  stat
# 22584  1701.08916v2  Prototypal analysis is introduced to overcome ...  stat
# 22100   1411.3803v1  Classical stochastic gradient methods are well...  stat
# 6190   1609.02631v1  This paper investigates the use of distributed...  stat
# 6583   1703.07506v1  Multivariate binary distributions can be decom...  stat
# ...             ...                                                ...   ...
# 5793    1206.5162v2  We present a general method for deriving colla...    cs
# 2863   1803.01489v1  We introduce Recurrent Predictive State Policy...  stat
# 14244   1402.1298v3  We analyse the matrix factorization problem. G...    cs
# 35275  cs/0211028v1  In this paper we name some of the advantages o...    cs
# 12550  1802.09548v1  As algorithms are increasingly used to make im...  stat
#
#                                                    title  year  \
# 3461   Deep Learning Methods for Efficient Large Scal...  2017
# 22584      Prototypal Analysis and Prototypal Regression  2017
# 22100  Stochastic Compositional Gradient Descent: Alg...  2014
# 6190   Distributed Processing of Biosignal-Database f...  2016
# 6583                  LogitBoost autoregressive networks  2017
# ...                                                  ...   ...
# 5793   Fast Variational Inference in the Conjugate Ex...  2012
# 2863          Recurrent Predictive State Policy Networks  2018
# 14244  Phase transitions and sample complexity in Bay...  2014
# 35275  Thinking Adaptive: Towards a Behaviours Virtua...  2002
# 12550  Human Perceptions of Fairness in Algorithmic D...  2018
#
#                                                 keywords
# 3461   [understanding, challenge, performed, augmente...
# 22584  [prototypal, introduced, shortcomings, archety...
# 22100  [classical, stochastic, minimizing, objective,...
# 6190   [investigates, distributed, processing, recogn...
# 6583   [multivariate, distributions, decomposed, univ...
# ...                                                  ...
# 5793   [collapsed, variational, inference, probabilis...
# 2863   [introduce, recurrent, predictive, recurrent, ...
# 14244  [factorization, measurement, applications, dic...
# 35275  [advantages, laboratories, behaviours, laborat...
# 12550  [algorithms, increasingly, important, decision...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 3461     [understanding, challenge, performed, augmente...
# 22584    [prototypal, introduced, shortcomings, archety...
# 22100    [classical, stochastic, minimizing, objective,...
# 6190     [investigates, distributed, processing, recogn...
# 6583     [multivariate, distributions, decomposed, univ...
#                                ...
# 33840    [industrial, increasingly, penetration, applic...
# 13839    [estimation, distribution, algorithms, probabi...
# 30141    [architecture, discriminative, efficiently, gr...
# 9013     [ungrammatical, grammaticality, discussed, agr...
# 5438     [framework, reinforcement, optimization, parti...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8823 words.
# Out of those 4554 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="b2348536-71e8-4dc4-8120-0b76c9942f3e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b2348536-71e8-4dc4-8120-0b76c9942f3e")) {                    Plotly.newPlot(                        "b2348536-71e8-4dc4-8120-0b76c9942f3e",                        [{"x":["performed","validation","efficient","challenge","augmented","understanding","sensitivity","introduced","embedding","reconstruction","prototypes","shortcomings","regression","approximates","convexity","supervised","probability","archetypal","procedure","applicability","developed","combination","interpretable","distributions","archetypes","nonsmooth","programming","interplay","gradients","functions","auxiliary","stochastic","nonlinear","iterations","objective","convergence","classical","stationary","involving","generated","minimizing","applications","estimation","algorithms","optimization","solutions","different","minimization","nonconvex","compositions","accelerated","compositional","composition","processing","classifier","significantly","exclusive","distributed","investigates","specifically","physiological","recognition","processed","unsupervised","multivariate","complexity","logitboost","autoregressive","conditionals","performance","dimensions","discussed","sophisticated","similarities","benchmark","differences","approaches","parallelized","estimator","dimension","experimentally","estimators","trivially","structures","distribution","considered","decomposed","conditional","univariate","structure","generative","conditions","treatment","observation","psychiatric","likelihood","observations","complementary","expensive","integrating","weighting","experience","interested","multinomial","inference","computational","implementation","variational","nonparametric","information","collected","accomplished","diagnosed","algorithm","implications","relationships","alternative","variables","approximation","disorders","categories","techniques","harvested","strategies","similarity","corresponding","architectures","measuring","photographs","retrieval","reduction","generalisation","dimensionality","augmentation","generalise","classification","satisfiable","treewidth","available","parameter","decomposition","generalized","structural","conjunctive","exhibiting","disproves","projection","established","hypergraphs","determines","satisfaction","correctly","framework","projections","equivalent","extensions","existence","polynomial","optimized","therefore","returning","tractability","extensively","efficiently","literature","evaluation","constraint","hypertree","expression","structured","component","cooperation","robustness","methodology","randomized","intervention","contribution","assessing","linguistic","contributions","reproduce","concretely","interventions","examining","individual","surprising","demonstrate","presented","components","normalized","theoretical","simulations","exponential","constraints","transient","expressions","negativity","illustrate","technical","regarding"],"y":[133,52,416,138,36,152,25,130,100,97,4,11,126,15,10,188,167,1,107,36,196,154,37,115,0,2,133,11,34,201,24,144,74,33,172,129,109,25,56,161,43,458,197,616,329,159,719,65,19,7,15,21,28,306,140,270,7,93,22,187,8,383,33,150,23,225,2,6,2,875,38,53,30,32,189,60,449,4,28,84,45,22,1,126,210,116,16,96,4,335,120,156,46,62,0,49,78,34,58,30,16,37,27,3,192,275,125,52,17,702,81,6,5,772,30,75,91,118,110,2,71,354,2,99,138,148,132,32,11,99,109,10,60,21,7,493,4,6,317,99,59,69,85,7,15,1,45,32,4,16,26,40,523,23,46,52,31,64,49,126,3,10,39,146,122,266,105,2,66,102,118,6,81,63,22,7,77,23,74,49,10,6,6,14,130,11,554,173,112,20,159,50,45,138,5,45,1,69,53,30],"type":"bar"},{"x":["performed","validation","efficient","challenge","augmented","und ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4554,), (4554, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8183333333333334

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Learning</span> <span style=''>Based</span> <span style=''>Dequantization</span> <span style=''>For</span> <span style=''>Image</span> <span style='background-color:rgba(0, 255, 0, 0.5294117647058824);'>Restoration</span> <span style=''>Against</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Extremely</span> <span style=''>Poor</span> <span style='background-color:rgba(0, 255, 0, 0.9473684210526316);'>Illumination</span> <br/><br/><span style=''>All</span> <span style=''>existing</span> <span style=''>image</span> <span style='background-color:rgba(0, 255, 0, 0.8285714285714286);'>enhancement</span> <span style=''>methods</span> <span style=''>such</span> <span style=''>as</span> <span style=''>HDR</span> <span style=''>tone</span> <span style=''>mapping</span> <span style=''>cannot</span> <span style=''>recover</span> <span style=''>AD</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>quantization</span> <span style=''>losses</span> <span style=''>due</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.5384615384615384);'>insufficient</span> <span style=''>or</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>excessive</span> <span style=''>lighting</span> <span style=''>(underflow</span> <span style=''>and</span> <span style=''>overflow</span> <span style=''>problems)</span> <span style=''>The</span> <span style=''>loss</span> <span style=''>of</span> <span style=''>image</span> <span style=''>details</span> <span style=''>due</span> <span style=''>to</span> <span style=''>AD</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>quantization</span> <span style=''>is</span> <span style=''>complete</span> <span style=''>and</span> <span style=''>it</span> <span style=''>cannot</span> <span style=''>be</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>recovered</span> <span style=''>by</span> <span style='background-color:rgba(0, 255, 0, 0.393939393939394);'>traditional</span> <span style=''>image</span> <span style='background-color:rgba(0, 255, 0, 0.47826086956521746);'>processing</span> <span style=''>methods</span> <span style=''>but</span> <span style=''>the</span> <span style=''>modern</span> <span style=''>data</span> <span style=''>driven</span> <span style=''>machine</span> <span style=''>learning</span> <span style=''>approach</span> <span style=''>offers</span> <span style=''>a</span> <span style=''>much</span> <span style=''>needed</span> <span style=''>cure</span> <span style=''>to</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>In</span> <span style=''>this</span> <span style=''>work</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>novel</span> <span style=''>approach</span> <span style=''>to</span> <span style=''>restore</span> <span style=''>and</span> <span style=''>enhance</span> <span style=''>images</span> <span style=''>acquired</span> <span style=''>in</span> <span style=''>low</span> <span style=''>and</span> <span style=''>uneven</span> <span style=''>lighting</span> <span style=''>First</span> <span style=''>the</span> <span style=''>ill</span> <span style='background-color:rgba(0, 255, 0, 0.9473684210526316);'>illumination</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.33333333333333337);'>algorithmically</span> <span style=''>compensated</span> <span style=''>by</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>emulating</span> <span style=''>the</span> <span style=''>effects</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.42180094786729855);'>artificial</span> <span style='background-color:rgba(0, 255, 0, 0.33333333333333337);'>supplementary</span> <span style=''>lighting</span> <span style=''>Then</span> <span style=''>a</span> <span style=''>DCNN</span> <span style=''>trained</span> <span style=''>using</span> <span style=''>only</span> <span style='backgr ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Ranking</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Biomarkers</span> <span style=''>Through</span> <span style=''>Mutual</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Information</span> <br/><br/><span style=''>We</span> <span style=''>study</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>information</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>theoretic</span> <span style=''>methods</span> <span style=''>for</span> <span style=''>ranking</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>biomarkers</span> <span style=''>In</span> <span style=''>clinical</span> <span style=''>trials</span> <span style=''>there</span> <span style=''>are</span> <span style=''>two</span> <span style=''>closely</span> <span style=''>related</span> <span style=''>types</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>biomarkers</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>predictive</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>prognostic</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>disentangling</span> <span style=''>them</span> <span style=''>is</span> <span style=''>a</span> <span style=''>key</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>challenge</span> <span style=''>Our</span> <span style=''>first</span> <span style=''>step</span> <span style=''>is</span> <span style=''>to</span> <span style=''>phrase</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>biomarker</span> <span style=''>ranking</span> <span style=''>in</span> <span style=''>terms</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimizing</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>information</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>theoretic</span> <span style=''>quantity</span> <span style=''>This</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>formalization</span> <span style=''>of</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>will</span> <span style=''>enable</span> <span style=''>us</span> <span style=''>to</span> <span style=''>derive</span> <span style=''>rankings</span> <span style=''>of</span> <span style=''>predictiveprognostic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>biomarkers</span> <span style=''>by</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimating</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>different</span> <span style=''>high</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensional</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>conditional</span> <span style=''>mutual</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>information</span> <span style=''>terms</span> <span style=''>To</span> <span style=''>estimate</span> <span style=''>these</span> <span style=''>terms</span> <span style=''>we</span> <span style=''>suggest</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>efficient</span> <span style=''>low</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensional</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approximations</span> <span style=''>and</span> <span style=''>we</span> <span style=''>derive</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>empirical</span> <span style=''>Bayes</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimator</span> <span style=''>which</span> <span style=''>is</span> <span style=''>suitable</span> <span style=''>for</span> <span style=''>small</span> <span style=''>or</span> <span style=''>sparse</span> <span style=''>datasets</span> <span style=''>Finally</span> <span style=''>we</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>introduce</span> <span style=''>a</span> <s ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Globally</span> <span style=''>Optimal</span> <span style=''>Training</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Generalized</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Polynomial</span> <span style=''>Neural</span> <span style=''>Networks</span> <span style=''>with</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Nonlinear</span> <span style=''>Spectral</span> <span style=''>Methods</span> <br/><br/><span style=''>The</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimization</span> <span style=''>problem</span> <span style=''>behind</span> <span style=''>neural</span> <span style=''>networks</span> <span style=''>is</span> <span style=''>highly</span> <span style=''>non</span> <span style=''>convex</span> <span style=''>Training</span> <span style=''>with</span> <span style='background-color:rgba(255, 0, 0, 0.30602409638554223);'>stochastic</span> <span style=''>gradient</span> <span style=''>descent</span> <span style=''>and</span> <span style=''>variants</span> <span style=''>requires</span> <span style=''>careful</span> <span style='background-color:rgba(255, 0, 0, 0.3242320819112628);'>parameter</span> <span style=''>tuning</span> <span style=''>and</span> <span style=''>provides</span> <span style=''>no</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>guarantee</span> <span style=''>to</span> <span style=''>achieve</span> <span style=''>the</span> <span style=''>global</span> <span style=''>optimum</span> <span style=''>In</span> <span style=''>contrast</span> <span style=''>we</span> <span style=''>show</span> <span style=''>under</span> <span style=''>quite</span> <span style=''>weak</span> <span style='background-color:rgba(255, 0, 0, 0.36734693877551017);'>assumptions</span> <span style=''>on</span> <span style=''>the</span> <span style=''>data</span> <span style=''>that</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>particular</span> <span style=''>class</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3513513513513513);'>feedforward</span> <span style=''>neural</span> <span style=''>networks</span> <span style=''>can</span> <span style=''>be</span> <span style=''>trained</span> <span style=''>globally</span> <span style=''>optimal</span> <span style=''>with</span> <span style=''>a</span> <span style=''>linear</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>convergence</span> <span style=''>rate</span> <span style=''>with</span> <span style=''>our</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>nonlinear</span> <span style=''>spectral</span> <span style=''>method</span> <span style=''>Up</span> <span style=''>to</span> <span style=''>our</span> <span style='background-color:rgba(0, 255, 0, 0.3861386138613861);'>knowledge</span> <span style=''>this</span> <span style=''>is</span> <span style=''>the</span> <span style=''>first</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>practically</span> <span style=''>feasible</span> <span style=''>method</span> <span style=''>which</span> <span style=''>achieves</span> <span style=''>such</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>guarantee</span> <span style=''>While</span> <span style=''>the</span> <span style=''>method</span> <span style=''>can</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>principle</span> <span style=''>be</span> <span style=''>applied</span> <span style=''>to</span> <span style=''>deep</span> <span style=''>networks</span> <span style=''>we</span> <span style=''>restrict</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>ourselves</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>simplicity</span> <span style=''>in</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>to</span> <span style=''>one</spa ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Fast</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Incremental</span> <span style=''>SVDD</span> <span style=''>Learning</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Algorithm</span> <span style=''>with</span> <span style=''>the</span> <span style=''>Gaussian</span> <span style=''>Kernel</span> <br/><br/><span style=''>Support</span> <span style=''>vector</span> <span style=''>data</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>description</span> <span style=''>(SVDD)</span> <span style=''>is</span> <span style=''>a</span> <span style=''>machine</span> <span style=''>learning</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>technique</span> <span style=''>that</span> <span style=''>is</span> <span style=''>used</span> <span style=''>for</span> <span style=''>single</span> <span style=''>class</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classification</span> <span style=''>and</span> <span style=''>outlier</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>detection</span> <span style=''>The</span> <span style=''>idea</span> <span style=''>of</span> <span style=''>SVDD</span> <span style=''>is</span> <span style=''>to</span> <span style=''>find</span> <span style=''>a</span> <span style=''>set</span> <span style=''>of</span> <span style=''>support</span> <span style=''>vectors</span> <span style=''>that</span> <span style=''>defines</span> <span style=''>a</span> <span style=''>boundary</span> <span style=''>around</span> <span style=''>data</span> <span style=''>When</span> <span style=''>dealing</span> <span style=''>with</span> <span style=''>online</span> <span style=''>or</span> <span style=''>large</span> <span style=''>data</span> <span style=''>existing</span> <span style=''>batch</span> <span style=''>SVDD</span> <span style=''>methods</span> <span style=''>have</span> <span style=''>to</span> <span style=''>be</span> <span style=''>rerun</span> <span style=''>in</span> <span style=''>each</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>iteration</span> <span style=''>We</span> <span style=''>propose</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>incremental</span> <span style=''>learning</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>for</span> <span style=''>SVDD</span> <span style=''>that</span> <span style=''>uses</span> <span style=''>the</span> <span style=''>Gaussian</span> <span style=''>kernel</span> <span style=''>This</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>builds</span> <span style=''>on</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>observation</span> <span style=''>that</span> <span style=''>all</span> <span style=''>support</span> <span style=''>vectors</span> <span style=''>on</span> <span style=''>the</span> <span style=''>boundary</span> <span style=''>have</span> <span style=''>the</span> <span style=''>same</span> <span style=''>distance</span> <span style=''>to</span> <span style=''>the</span> <span style=''>center</span> <span style=''>of</span> <span style=''>sphere</span> <span style=''>in</span> <span style=''>a</span> <span style=''>higher</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensional</span> <span style=''>feature</span> <span style=''>space</span> <span style=''>as</span> <span style=''>mapped</span> <span style=''>by</span> <span style=''>the</span> <span style=''>Gaussian</span> <span style=''>kernel</span> <span style=''>function</span> <span style=''>Each</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>iteration</span> <span style=''>involves</span> <span style=''>only</span> <span style=''>the</span> <span style=''>existing</span> <span style=''>support</span> <span style=''>vectors</span> <span style=''>and</span> <span style=''>the</span> <span style=''>new</span> <span styl ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	experimental (0.13173866476258478)
# 	segmentation (0.07033202427704391)
# 	processing (0.10924669760799714)
# 	architecture (0.0917529453766512)
# 	representation (0.14209210996072832)
# 	information (0.2506247768654052)
# 	different (0.25669403784362727)
# 	detection (0.1267404498393431)
# 	convolutional (0.135308818279186)
# 	recognition (0.13673687968582648)
#
# Some Statistics words are:
# 	likelihood (0.1025512756378189)
# 	theoretical (0.14607303651825912)
# 	variables (0.13856928464232116)
# 	statistical (0.15457728864432216)
# 	estimation (0.17008504252126064)
# 	distribution (0.18209104552276137)
# 	dimensional (0.18659329664832416)
# 	inference (0.19309654827413708)
# 	algorithm (0.40370185092546274)
# 	regression (0.17808904452226113)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="92d8e9e3-8bb6-47d4-a11b-04f68a28f2a3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("92d8e9e3-8bb6-47d4-a11b-04f68a28f2a3")) {                    Plotly.newPlot(                        "92d8e9e3-8bb6-47d4-a11b-04f68a28f2a3",                        [{"x":["performed","validation","efficient","challenge","augmented","understanding","sensitivity","introduced","embedding","reconstruction","prototypes","shortcomings","regression","approximates","convexity","supervised","probability","archetypal","procedure","applicability","developed","combination","interpretable","distributions","archetypes","nonsmooth","programming","interplay","gradients","functions","auxiliary","stochastic","nonlinear","iterations","objective","convergence","classical","stationary","involving","generated","minimizing","applications","estimation","algorithms","optimization","solutions","different","minimization","nonconvex","compositions","accelerated","compositional","composition","processing","classifier","significantly","exclusive","distributed","investigates","specifically","physiological","recognition","processed","unsupervised","multivariate","complexity","logitboost","autoregressive","conditionals","performance","dimensions","discussed","sophisticated","similarities","benchmark","differences","approaches","parallelized","estimator","dimension","experimentally","estimators","trivially","structures","distribution","considered","decomposed","conditional","univariate","structure","generative","conditions","treatment","observation","psychiatric","likelihood","observations","complementary","expensive","integrating","weighting","experience","interested","multinomial","inference","computational","implementation","variational","nonparametric","information","collected","accomplished","diagnosed","algorithm","implications","relationships","alternative","variables","approximation","disorders","categories","techniques","harvested","strategies","similarity","corresponding","architectures","measuring","photographs","retrieval","reduction","generalisation","dimensionality","augmentation","generalise","classification","satisfiable","treewidth","available","parameter","decomposition","generalized","structural","conjunctive","exhibiting","disproves","projection","established","hypergraphs","determines","satisfaction","correctly","framework","projections","equivalent","extensions","existence","polynomial","optimized","therefore","returning","tractability","extensively","efficiently","literature","evaluation","constraint","hypertree","expression","structured","component","cooperation","robustness","methodology","randomized","intervention","contribution","assessing","linguistic","contributions","reproduce","concretely","interventions","examining","individual","surprising","demonstrate","presented","components","normalized","theoretical","simulations","exponential","constraints","transient","expressions","negativity","illustrate","technical","regarding","approximations","empirical","confidence","parametric","identification","individuals","differential","preferences","misclassification","knowledge","numerically","minimizes","preference","posterior","assumptions","sequentially","preferred","conducted","alternatives","constructed","scenarios","continuum","maximally","adaptively","theoretic","summation","quadratic","logarithm","especially","potential","traditional","quantization","excellent","bottlenecks","properties","quantized","illustrative","criterion","comparing","decreases","suggesting","expressing","polynomials","approximate","increased","universal","requirement","exponentially","logarithmically","approximators","realistic","explicitly","modification","represents"," ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	archetypes
# 	psychiatric
# 	correspondingly
# 	divergent
# 	literally
# 	abandonment
# 	parametrisation
# 	subgroups
# 	provision
# 	hypernetworks
# 	hypernetwork
# 	supercomputers
# 	compromised
# 	penalization
# 	asymptotics
# 	regularizes
# 	distributionally
# 	marginalisation
# 	factorize
# 	straggler
# Some words which never appear in Statistics papers:
# 	harvested
# 	photographs
# 	satisfiable
# 	treewidth
# 	returning
# 	hypertree
# 	sensorimotor
# 	meaningless
# 	utterance
# 	discourse
# 	unregistered
# 	monocular
# 	stylistic
# 	paraphrase
# 	redundancies
# 	centrally
# 	stabilize
# 	defensive
# 	multiobjective
# 	premature

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.0708758137820905e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7825
